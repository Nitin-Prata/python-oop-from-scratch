# %%
L = [1,2,3]

# L.upper() ->  # AttributeError: 'list' object has no attribute 'upper'

# %%
s = 'hello'
# s.append('x')  -> # AttributeError: 'str' object has no attribute 'append'

# %%
L = [1,2,3]
print(type(L))
# Out:
# <class 'list'>

# %%
s = [1,2,3]
s
# Out:
# [1, 2, 3]

# %%
# syntax to create an object

#objectname = classname()

# %%
# object literal
L = [1,2,3]

# %%
L = list()
L
# Out:
# []

# %%
s = str()
s
# Out:
# ''

# %%
# class name
# Pascal Case

## HelloWorld

# %%
class Atm:

    # constructor 
    def __init__(self):
        print(id(self))
        self.pin = ''
        self.balance = 0
        # self.menu()

    def menu(self):
        user_input = input("""
        Hi how can I help you?
        1. Press 1 to create pin
        2. Press 2 to change pin
        3. Press 3 to check balance
        4. Press 4 to withdraw
        5. Anythig else to exit
        """)

        if user_input == '1':
            self.create_pin()
        # create pin
        elif user_input == '2':
            self.change_pin()
        #change pin
        elif user_input == '3':
            self.check_balance()
        # check balance
        elif user_input == '4':
            self.withdraw()
        # withdraw
        else:
            exit() 

    def create_pin(self):
        user_pin = input('enter your pin')
        self.pin = user_pin

        user_balance = int(input('enter balance'))
        self.balance = user_balance

        print('pin created successfuly')
        self.menu()

    def change_pin(self):
        old_pin = input('enter old pin')

        if old_pin == self.pin:
            new_pin = input('enter new pin')
            self.pin = new_pin
            print('pin change successful')
            self.menu()
            # let him change the pin

        else:
            print('can not change')
            self.menu()

    def check_balance(self):
        user_pin = input('enter your pin')
        
        if user_pin == self.pin:
            print('your balance is',self.balance)
            self.menu()

        else:
            print('pin is not correct')
            self.menu()
            
    
    def withdraw(self):
        user_pin = input('enter the pin')

        if user_pin == self.pin:
            # allow to withdraw
            amount = int(input('enter the amount'))
            if amount <= self.balance:
                self.balance = self.balance - amount
                print('withdrawl successful',self.balance)
            else:
                print('u are so poor')
        else:
            print('sale chor')
        self.menu()

# %%
obj = Atm()
# Out:
# 2217400113680

# %%
id(obj)
# Out:
# 2217400113680

# %%
# identify which one is fun and which one is method
L = [1,2,3]
len(L) # fun -> becoz outside the list class
L.append(4) # method -> why becz append is a fun which is implemeted inside the List class

# %% [markdown]
# ### create a fraction data type

# %%
class Fraction:

# parameterized constructor
    def __init__(self,x,y):
        self.num = x
        self.den = y

    def __str__(self):
        return '{}/{}'.format(self.num,self.den)
    
    def __add__(self,other):
        new_num = self.num*other.den + other.num*self.den
        new_den = self.den * other.den

        return '{}/{}'.format(new_num,new_den)
    
    def __sub__(self,other):
        new_num = self.num*other.den - other.num*self.den
        new_den = self.den * other.den

        return '{}/{}'.format(new_num,new_den)
    
    def __mul__(self,other):
        new_num = self.num*other.num 
        new_den = self.den * other.den

        return '{}/{}'.format(new_num,new_den)
    
    
    def __truediv__(self,other):
        new_num = self.num*other.den 
        new_den = self.den * other.num

        return '{}/{}'.format(new_num,new_den)

# %%
fr1 = Fraction(3,5)
fr2 = Fraction(9,1)

# %%
print(fr1+fr2)
print(fr1-fr2)
print(fr1*fr2)
print(fr1/fr2)
# Out:
# 48/5
# -42/5
# 27/5
# 3/45
